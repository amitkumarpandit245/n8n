# %%
from google import genai

client = genai.Client(api_key="AIzaSyDhCwOrgLPLuYdcM7a6uC_Q_7dptSmPmxY")

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="What is AI",
)

print(response.text)
# Out:
# **AI**, or **Artificial Intelligence**, is a field of computer science that focuses on creating systems capable of performing tasks that typically require human intelligence.
#
# While humans use their brains to perceive, reason, and learn, AI uses **algorithms** (sets of rules) and vast amounts of **data** to mimic those functions.
#
# Here is a breakdown of how it works, the different types, and how we use it today.
#
# ---
#
# ### 1. How does AI work?
# Most modern AI doesn't "think" like a human; instead, it uses a process called **Machine Learning (ML)**.
# *   **Learning from Data:** Instead of being programmed with every possible rule, the AI is fed millions of examples. For example, to teach an AI to recognize a cat, you show it millions of photos of cats.
# *   **Pattern Recognition:** The AI identifies patterns in that data that a human might never notice.
# *   **Prediction:** When shown a new, unseen photo, the AI calculates the probability that it matches the "cat" patterns it learned.
#
# ### 2. The Three Levels of AI
# AI is generally categorized by its capabilities:
#
# *   **Narrow AI (Weak AI):** This is the only type of AI that exists today. It is designed to perform a specific task—like checking the weather, playing chess, or generating text. It cannot do anything outside its specific programming.
# *   **General AI (AGI or Strong AI):** This is a theoretical version of AI that would have the ability to understand, learn, and apply intelligence to any problem, much like a human. We are not there yet.
# *   **Super AI:** A theoretical future where AI surpasses human intelligence across all fields, including creativity, wisdom, and social skills.
#
# ### 3. Generative AI (The current "Boom")
# You have likely heard of tools like **ChatGPT, Claude, or Midjourney**. These are examples of **Generative AI**. Unlike traditional AI that simply categorizes data (e.g., "This is a cat"), Generative AI can **create new content** (text, images, music, or code) based on the patterns it has learned from existing data.
#
# ### 4. Common Real-World Examples
# AI is already part of our daily lives, often in ways we don't notice:
# *   **Recommendation Systems:** Netflix suggesting a movie or Amazon suggesting a product.
# *   **Virtual Assistants:** Siri, Alexa, and Google Assistant.
# *   **Navigation:** Google Maps using AI to predict traffic and suggest the fastest route.
# *   **Facial Recognition:** Unlocking your phone with your face.
# *   **Generative Tools:** Writing emails, creating art, or summarizing long documents.
#
# ### 5. Why is AI a big deal right now?
# AI is evolving rapidly because of three main factors:
# 1.  **Computing Power:** Computers are now fast enough to process massive amounts of data in seconds.
# 2.  **Big Data:** The internet has provided a near-infinite library of text and images for AI to learn from.
# 3.  **Better Algorithms:** Researchers have discovered more efficient ways for "Neural Networks" (AI models inspired by the human brain) to learn.
#
# ### 6. Risks and Ethics
# Because AI is so powerful, it brings significant challenges:
# *   **Bias:** If an AI learns from data that contains human prejudice, the AI will also be biased.
# *   **Jobs:** AI can automate many tasks, which may lead to shifts in the labor market.
# *   **Misinformation:** AI can be used to create very convincing "deepfakes" or fake news.
# *   **Privacy:** AI systems require massive amounts of data, raising concerns about how that data is collected and used.
#
# ### Summary
# In short, **AI is a tool that allows computers to learn from experience and perform complex tasks.** It is not "sentient" (it doesn't have feelings or consciousness), but it is incredibly good at processing information and solving problems at a scale that humans cannot match.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Amit Kumar\AppData\Local\Programs\Python\Python314\python.exe

# %%
import sys, subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "-U", "pip", "google-genai"])
# Out:
# 0
